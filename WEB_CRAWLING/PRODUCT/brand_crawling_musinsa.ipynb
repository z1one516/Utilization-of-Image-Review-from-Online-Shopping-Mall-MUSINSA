# %%
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# %%
path  = r"C:\Users\NT550\Downloads\chromedriver_win32 (1)\chromedriver.exe"
s = Service(path)
driver = webdriver.Chrome(service=s)
driver.get('https://www.musinsa.com/brands')
time.sleep(2)

# %%
brand = []
for page in range(3, 13):
    time.sleep(1)
    driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/section/div[3]/div/div[2]/div/div/a[{0}]'.format(page)).send_keys(Keys.ENTER)
    for i in range(1, 101):
        name = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/section/div[2]/div/ul/li[{0}]/dl/dt/a'.format(i)).text
        name_eng = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/section/div[2]/div/ul/li[{0}]/dl/dd/a'.format(i)).text.split(sep = "(")[0].rstrip()
        brand.extend([name, name_eng])

# %%
brand
# Out:
# ['무신사 스탠다드',
#  'MUSINSA STANDARD',
#  '아디다스',
#  'ADIDAS',
#  '수아레',
#  'SUARE',
#  '아식스',
#  'ASICS',
#  '마뗑킴',
#  'MATIN KIM',
#  '어반드레스',
#  'AVANDRESS',
#  '예일',
#  'YALE',
#  '굿라이프웍스',
#  'GLW',
#  '푸마',
#  'PUMA',
#  '토피',
#  'TOFFEE',
#  '반스',
#  'VANS',
#  '에스피오나지',
#  'ESPIONAGE',
#  '노스페이스',
#  'THE NORTH FACE',
#  '드로우핏',
#  'DRAW FIT',
#  '파르티멘토',
#  'PARTIMENTO',
#  '커버낫',
#  'COVERNAT',
#  '락피쉬웨더웨어',
#  'ROCKFISH WEATHERWEAR',
#  '디스이즈네버댓',
#  'THISISNEVERTHAT',
#  '도프제이슨',
#  'DOFFJASON',
#  '트래블',
#  'TRAVEL',
#  '폴로 랄프 로렌',
#  'POLO RALPH LAUREN',
#  '컨버스',
#  'CONVERSE',
#  '우포스',
#  'OOFOS',
#  '제로',
#  'XERO',
#  '리',
#  'LEE',
#  '트릴리온',
#  'TRILLION',
#  '아웃스탠딩',
#  'OUTSTANDING',
#  '코드그라피',
#  'CODEGRAPHY',
#  '스파오',
#  'SPAO',
#  '와릿이즌',
#  'WHATITISNT',
#  '배럴',
#  'BARREL',
#  '캘빈클라인 진',
#  'CALVIN KLEIN JEANS',
#  '하이어스',
#  'HIGHUS',
#  '잔스포츠',
#  'JANSPORT',
#  '내셔널지오그래픽',
#  'NATIONALGEOGRAPHIC',
#  '세터',
#  'SATUR',
#  '뉴발란스',
#  'NEW BALANCE',
#  '스컬프터',
#  'SCULPTOR',
#  '엄브로',
#  'UMBRO',
#  '제멋',
#  'JEMUT',
#  '낫포너드',
#  'NOT4NERD',
#  '유니폼브릿지',
#  'UNIFORM BRIDGE',
#  '엠엘비',
#  'MLB',
#  '안다르',
#  'ANDAR',
#  '피지컬 에듀케이션 디파트먼트',
#  'PHYSICAL EDUCATION DEPARTMENT',
#  '꼼파뇨',
#  'CPGN STUDIO',
#  '노매뉴얼',
#  'NOMANUAL',
#  '디스커버리 익스페디션',
#  'DISCOVERY EXPEDITION',
#  '메종미네드',
#  'MAISON MINED',
#  '생로랑',
#  'SAINT LAURENT',
#  '슈펜',
#  'SHOOPEN',
#  '마인드브릿지',
#  'MINDBRIDGE',
#  '에이치덱스',
#  'HDEX',
#  '디미트리블랙',
#  'DIMITRI BLACK',
#  '엑스톤즈',
#  'XTONZ',
#  '23.65',
#  '23.65',
#  '퍼스텝',
#  'PERSTEP',
#  '페플',
#  'FP142',
#  '토앤토',
#  'TAW&TOE',
#  '마르디 메크르디',
#  'MARDI MERCREDI',
#  '나이스고스트클럽',
#  'NICE GHOST CLUB',
#  '로맨틱크라운',
#  'ROMANTIC CROWN',
#  '파르티멘토 우먼',
#  'PARTIMENTO WOMEN',
#  '디젤',
#  'DIESEL',
#  '브라운브레스',
#  'BROWNBREATH',
#  '지오다노',
#  'GIORDANO',
#  '가까이 유니언즈',
#  'GAKKAI UNIONS',
#  '캘빈클라인 언더웨어',
#  'CALVIN KLEIN UNDERWEAR',
#  '시그니처',
#  'SIGNATURE',
#  '아메스 월드와이드',
#  'AMES-WORLDWIDE',
#  '엠엠엘지',
#  'MMLG',
#  '닥터마틴',
#  'DR.MARTENS',
#  '어반디타입',
#  'URBANDTYPE',
#  '리트리버클럽',
#  'RETRIEVER CLUB',
#  '에잇세컨즈',
#  '8SECONDS',
#  '어게인스트 올 오즈',
#  'AGAINST ALL ODDS',
#  '브렌슨',
#  'BRENSON',
#  '비슬로우',
#  'BESLOW',
#  '테이크이지',
#  'TAKEASY',
#  '우알롱',
#  'WOOALONG',
#  '소버먼트',
#  'SOVERMENT',
#  '코닥',
#  'KODAK',
#  '모드나인',
#  'MODNINE',
#  '예스아이씨',
#  'YESEYESEE',
#  '메종 마르지엘라',
#  'MAISON MARGIELA',
#  '리끌로우',
#  'RECLOW',
#  '지프',
#  'JEEP',
#  '러브이즈트루',
#  'LUV IS TRUE',
#  '크록스',
#  'CROCS',
#  '캐치볼',
#  'CATCH BALL',
#  '후아유',
#  'WHO.A.U',
#  '엘엠씨',
#  'LMC',
#  '비전스트릿웨어',
#  'VISION STREETWEAR',
#  '마리떼',
#  'MARITHE FRANCOIS GIRBAUD',
#  '그루브라임',
#  'GROOVE RHYME',
#  '프렌다',
#  'PRENDA',
#  '스노우피크 어패럴',
#  'SNOWPEAK APPAREL',
#  '팔렛',
#  'FALLETT',
#  '오아이오아이',
#  'OIOI',
#  '인템포무드',
#  'INTEMPOMOOD',
#  '브랜디드',
#  'BRANDED',
#  '아미',
#  'AMI',
#  '필루미네이트',
#  'FILLUMINATE',
#  '비바스튜디오',
#  'VIVASTUDIO',
#  '아이러니포르노 화이트라인',
#  'IRONYPORNO WHITELINE',
#  '슬로우애시드',
#  'SLOW ACID',
#  '밀로',
#  'MILLO',
#  '디키즈',
#  'DICKIES',
#  '일꼬르소',
#  'IL CORSO',
#  '말본 골프',
#  'MALBON GOLF',
#  '프라다',
#  'PRADA',
#  '1993스튜디오',
#  '1993STUDIO',
#  '스탠드오일',
#  'STAND OIL',
#  '아카이브 볼드',
#  'ARCHIVE BOLD',
#  '프리즘웍스',
#  'FRIZMWORKS',
#  '밸롭',
#  'BALLOP',
#  '키뮤어',
#  'KIIMUIR',
#  '마크모크',
#  'MAC MOC',
#  '이벳필드',
#  'EBBETSFIELD',
#  '보테가베네타',
#  'BOTTEGA VENETA',
#  '하 아카이브',
#  'HAHARCHIVE',
#  '츄바스코',
#  'CHUBASCO',
#  '무신사 스탠다드 스포츠',
#  'MUSINSA STANDARD SPORTS',
#  '니티드',
#  'KNITTED',
#  '배드블러드',
#  'BADBLOOD',
#  '엘무드',
#  'LMOOD',
#  '더콜디스트모먼트',
#  'THE COLDEST MOMENT',
#  '챔피온',
#  'CHAMPION',
#  '노이어',
#  'NOIRER',
#  '르아르',
#  'LEIRE',
#  '타입서비스',
#  'TYPESERVICE',
#  '쿠어',
#  'COOR',
#  '네스티팬시클럽',
#  'NASTY FANCY CLUB',
#  '페넥',
#  'FENNEC',
#  '토마스모어',
#  'THOMASMORE',
#  '미쏘',
#  'MIXXO',
#  '언더아머',
#  'UNDERARMOUR',
#  '오드펄',
#  'ODDPEARL',
#  '와이케이',
#  'WAIKEI',
#  '주앙옴므',
#  'JUAN HOMME',
#  '데이',
#  'THEY',
#  '살로몬 스포츠스타일',
#  'SALOMON SPORTSTYLE',
#  '클로브',
#  'CLOVE',
#  '마하그리드',
#  'MAHAGRID',
#  '어나더 오피스',
#  'ANOTHER OFFICE',
#  '후러브스아트',
#  'WHOLOVESART',
#  '톰브라운',
#  'THOM BROWNE',
#  '어커버',
#  'ACOVER',
#  '에이이에이이',
#  'AEAE',
#  '비비안 웨스트우드',
#  'VIVIENNE WESTWOOD',
#  '아노블리어',
#  'ANOBLIR',
#  '에이카화이트',
#  'AECA WHITE',
#  '뉴에라',
#  'NEW ERA',
#  '앤더슨벨',
#  'ANDERSSON BELL',
#  '비긴202',
#  'BEGIN202',
#  '플랙',
#  'PLAC',
#  '마스마룰즈',
#  'MASMARULEZ',
#  '코데즈컴바인 이너웨어',
#  'CODES COMBINE INNERWEAR',
#  '커스텀어클락',
#  'COSTUME O’CLOCK',
#  '플루크',
#  'FLUKE',
#  '리복',
#  'REEBOK',
#  '킨',
#  'KEEN',
#  '비브이에이치',
#  'BVH EYEWEAR',
#  '그라미치',
#  'GRAMICCI',
#  '미니멀프로젝트',
#  'MINIMALPROJECT',
#  '시티브리즈',
#  'CITY BREEZE',
#  '인사일런스',
#  'INSILENCE',
#  '척',
#  'CHUCK',
#  '르마드',
#  'LEMARD',
#  '로드 존 그레이',
#  'LORD JOHN GREY',
#  '밀리언코르',
#  'MILLIONCOR',
#  '일오공칠',
#  'IL-O-GONG-CHIL',
#  '발렌시아가',
#  'BALENCIAGA',
#  '어널러코드',
#  'ANOLORCODE',
#  '게인스보로',
#  'GAINSBORO',
#  '위캔더스',
#  'WKNDRS',
#  '판도라핏',
#  'PANDORAFIT',
#  '더 아이덴티티 프로젝트',
#  'THE IDENTITY PROJECT',
#  '닉앤니콜',
#  'NICK&NICOLE',
#  '레더리',
#  'LEATHERY',
#  '야세',
#  'YASE',
#  '키르시',
#  'KIRSH',
#  '휠라',
#  'FILA',
#  '어뉴골프',
#  'ANEW GOLF',
#  '다이나핏',
#  'DYNAFIT',
#  '에즈카톤',
#  'EZKATON',
#  '1989스탠다드',
#  '1989STANDARD',
#  '빈트릴 골프',
#  'BEENTRILL GOLF',
#  '페이탈리즘',
#  'FATALISM',
#  '위더로드',
#  'WETHEROAD',
#  '더블유브이프로젝트',
#  'WV PROJECT',
#  '제이에스티나',
#  'JESTINA',
#  '에프씨엠엠',
#  'FCMM',
#  '로엠',
#  'ROEM',
#  '몬스터리퍼블릭',
#  'MONSTER REPUBLIC',
#  '에즈이프 캘리',
#  'ASIF CALIE',
#  '로우로우',
#  'RAWROW',
#  '메종 키츠네',
#  'MAISON KITSUNE',
#  '크리틱',
#  'CRITIC',
#  '벤힛',
#  'VENHIT',
#  '오더아카이브',
#  'ORDER ARCHIVE',
#  '가니',
#  'GANNI',
#  '피스워커',
#  'PIECE WORKER',
#  '허그본',
#  'HUGVONE',
#  '빅유니온',
#  'BIG UNION',
#  '포트너스',
#  'FOTTNERS',
#  '포터리',
#  'POTTERY',
#  '로맨틱무브',
#  'ROMANTIC MOVE',
#  '디써티원',
#  'DTHIRTYONE',
#  '예루살렘 샌들',
#  'JERUSALEM SANDALS',
#  '비터셀즈',
#  'BITTERCELLS',
#  '마틴플랜',
#  'MARTIN PLAN',
#  '더니트컴퍼니',
#  'THEKNITCOMPANY',
#  '미나브',
#  'MINAV',
#  '아조바이아조',
#  'AJOBYAJO',
#  '헤라',
#  'HERA',
#  '데케트',
#  'DECET',
#  '슬로우 레코드 하우스',
#  'SLOW RECORD HOUSE',
#  '랩12',
#  'LAB12',
#  '맥우드건',
#  'MAGOODGAN',
#  '나체',
#  'NACHE',
#  '레이지비',
#  'LAZYBEE',
#  '라코스테',
#  'LACOSTE',
#  '세인트새틴',
#  'SAINTSATIN',
#  '이스트쿤스트',
#  'IST KUNST',
#  '피렌체 아뜨리에',
#  'FIRENZE ATELIER',
#  '테일러메이드',
#  'TAYLOR MADE',
#  '어프레쉬',
#  'AFRESH',
#  '카비시',
#  'CAVISH',
#  '세븐셀라',
#  'SEVENSELAH',
#  '애프터프레이',
#  'AFTERPRAY',
#  '팀코믹스',
#  'TIMCOMIX',
#  '로라로라',
#  'ROLAROLA',
#  '그레이버',
#  'GRAVER',
#  '콜릿',
#  'KOLEAT',
#  '블랙몬스터핏',
#  'BLACK MONSTER FIT',
#  '오니츠카타이거',
#  'ONITSUKA TIGER',
#  '퀵실버',
#  'QUIKSILVER',
#  '맥키',
#  'MACKY',
#  '노스페이스 키즈',
#  'THE NORTH FACE KIDS',
#  '앵글런',
#  'ANGLAN',
#  '아페쎄',
#  'A.P.C.',
#  '골든베어',
#  'GOLDEN BEAR',
#  '트레통',
#  'TRETORN',
#  '라퍼',
#  'LAUGHER',
#  '티떠블유엔',
#  'TWN',
#  '미니멀웍스',
#  'MINIMALWORKS',
#  '백컨트리',
#  'BACKCOUNTRY',
#  '널디',
#  'NERDY',
#  '듀테로',
#  'DEUTERO',
#  '제테스',
#  'ZETES',
#  '소니',
#  'SONY',
#  '블랭크룸',
#  'BLANK ROOM',
#  '아디다스 언더웨어',
#  'ADIDAS UNDERWEAR',
#  '질바이질스튜어트',
#  'JILL BY JILLSTUART',
#  '헤드',
#  'HEAD',
#  '본챔스',
#  'BORN CHAMPS',
#  '86로드',
#  '86ROAD',
#  '마르디 메크르디 악티프',
#  'MARDI MERCREDI ACTIF',
#  '캉골',
#  'KANGOL',
#  '나인제트',
#  'NINEZ',
#  '게스언더웨어',
#  'GUESS UNDERWEAR',
#  '론론',
#  'RONRON',
#  '그로브',
#  'GROVE',
#  '분크',
#  'VUNQUE',
#  '엠엠식스',
#  'MM6 Maison Margiela',
#  '아코스튜디오스페이스',
#  'AQOstudiospace',
#  '살로몬',
#  'SALOMON',
#  '위글위글',
#  'WIGGLE WIGGLE',
#  '아레나',
#  'ARENA',
#  '래리클락',
#  'LARRY CLARK',
#  '오드스튜디오',
#  'ODDSTUDIO',
#  '페라가모',
#  'SALVATORE FERRAGAMO',
#  '엑스트라오디너리',
#  'EXTRAORDINARY',
#  '로에일',
#  'LOEIL',
#  '세인트페인',
#  'SAINTPAIN',
#  '파브레가',
#  'FABREGAT',
#  '플레이스 스튜디오',
#  'PLACE STUDIO',
#  '논플로어',
#  'NONFLOOR',
#  '멜란지 마스터',
#  'MELANGE MASTER',
#  '카멜워크',
#  'CAMEL WORK',
#  '브라이튼 캐리어',
#  'BRIGHTON',
#  '르꼬끄',
#  'LECOQ',
#  '아모멘토',
#  'AMOMENTO',
#  '머렐',
#  'MERRELL',
#  '글리머',
#  'GLIMMER',
#  '미우미우',
#  'MIU MIU',
#  '제너럴아이디어',
#  'GENERALIDEA',
#  '슈퍼서브',
#  'SUPERSUB',
#  '질 샌더',
#  'JIL SANDER',
#  '밈더워드로브',
#  'MIMTHEWARDROBE',
#  '메인부스',
#  'MAINBOOTH',
#  '아워스코프',
#  'OURSCOPE',
#  '칼린',
#  'CARLYN',
#  '바우프',
#  'BAUF',
#  '모더먼트',
#  'MODERMENT',
#  '게스',
#  'GUESS',
#  '아르반',
#  'AREUBAN',
#  '51퍼센트',
#  '51PERCENT',
#  '모즈모즈',
#  'MOZMOZ',
#  '미즈노',
#  'MIZUNO',
#  '머슬암드',
#  'MUSCLE ARMED',
#  '아이더',
#  'EIDER',
#  '패블러스아카이브',
#  'FABULOUS ARCHIVE',
#  '케즈',
#  'KEDS',
#  '언아웃핏',
#  'AOTT',
#  '일리고',
#  'ILLIGO',
#  '디앤에스알',
#  'DNSR',
#  '시엔느',
#  'SIENNE',
#  '트레셔',
#  'THRASHER',
#  '오가프',
#  'OGARP',
#  '오디너리홀리데이',
#  'ORDINARY HOLIDAY',
#  '토우토우 아카이브',
#  'TOWTOW ARCHIVE',
#  '마르니',
#  'MARNI',
#  '자크뮈스',
#  'JACQUEMUS',
#  '애드오프',
#  'ADDOFF',
#  '데상트',
#  'DESCENTE',
#  '솔트앤초콜릿',
#  'SALT AND CHOCOLATE',
#  '해비즘',
#  'HAVISM',
#  '알브이디',
#  'RVD',
#  '셀린느',
#  'CELINE',
#  '테바',
#  'TEVA',
#  '마크 곤잘레스',
#  'MARK GONZALES',
#  '폴스미스',
#  'PAUL SMITH',
#  '앨빈클로',
#  'ALVINCLO',
#  '파인드카푸어',
#  'FIND KAPOOR',
#  '포맨트',
#  'FORMENT',
#  '스케쳐스',
#  'SKECHERS',
#  '젝시오',
#  'XXIO',
#  '크럼프',
#  'CRUMP',
#  '보다나',
#  'VODANA',
#  '베이직하우스',
#  'BASIC HOUSE',
#  '구찌',
#  'GUCCI',
#  '엔에프엘',
#  'NFL',
#  '플레어업',
#  'FLAREUP',
#  '스퀘어라인',
#  'SQUARELINE',
#  '오프닝프로젝트',
#  'OPENING PROJECT',
#  '필인더블랭크',
#  'FILLINTHEBLANK',
#  '피그먼트',
#  'PIGMENT',
#  '무르',
#  'MUR',
#  '썸플레이스',
#  'SOME PLACE',
#  '코오롱스포츠',
#  'KOLON SPORT',
#  '라티젠',
#  'LARTIGENT',
#  '엘리메노',
#  'ELIMENO',
#  '벤시몽',
#  'BENSIMON',
#  '넌블랭크',
#  'NONBLANK',
#  '어썸스튜디오',
#  'AWESOME STUDIO',
#  '그레일즈',
#  'GRAILZ',
#  '제로플래닛',
#  'ZEROPLANET',
#  '아그넬',
#  'AGNEL',
#  '네이키드니스',
#  'NEIKIDNIS',
#  '식스핏',
#  '6FT',
#  '오호스',
#  'OJOS',
#  '프로스펙스',
#  'PROSPECS',
#  '피스메이커',
#  'PIECE MAKER',
#  '어반스터프',
#  'URBANSTOFF',
#  '유앤엘씨',
#  'U&LC',
#  '던스트 포 우먼',
#  'DUNST FOR WOMEN',
#  '마카사이트',
#  'MACASITE',
#  '조거쉬',
#  'JOEGUSH',
#  '갭',
#  'GAP',
#  '인더스트',
#  'INDUST',
#  '트립르센스',
#  'TRIP LE SENS',
#  '아일랜드슬리퍼',
#  'ISLANDSLIPPER',
#  '비얼디드키드',
#  'BEARDED KID',
#  '글랙',
#  'GLACK',
#  '제이반스 클래식',
#  'JBANS CLASSIC',
#  '아메리칸투어리스터',
#  'AMERICAN TOURISTER',
#  '솔트워터',
#  'SALTWATER',
#  '로얄라이프',
#  'ROYALLIFE',
#  '레이디 볼륨',
#  'LADY VOLUME',
#  '프라이',
#  'FREI',
#  '레스트앤레크레이션',
#  'REST&RECREATION',
#  '클리오',
#  'CLIO',
#  '써네이',
#  'SUNNEI',
#  '에씰미',
#  'ESEELMI',
#  '벤 데이비스',
#  'BEN DAVIS',
#  '티비제이',
#  'TBJ',
#  '디아도라',
#  'diadora',
#  '라이프워크',
#  'LIFEWORK',
#  '와일드 브릭스',
#  'WILD BRICKS',
#  '매스노운',
#  'MASSNOUN',
#  '이우가마카라스',
#  'IUGAMAKARAS',
#  '라이즈앤빌로우',
#  'RISE&BELOW',
#  '스컬피그',
#  'SKULLPIG',
#  '비레디',
#  'BE READY',
#  '타미힐피거',
#  'TOMMY HILFIGER',
#  '디올',
#  'DIOR',
#  '몽돌',
#  'MONGDOL',
#  '비나제이',
#  'VINAJ',
#  '도미넌트',
#  'DOMINANT',
#  '챌린저',
#  'CHALLENGER',
#  '리에티',
#  'RIETI',
#  '유희',
#  'YOUHEE',
#  '배드인배드',
#  'BADINBAD',
#  '포즈간츠',
#  'POSEGANCH',
#  '시눈',
#  'SINOON',
#  '톤즈',
#  'TONES',
#  '알렉산더 맥퀸',
#  'ALEXANDER McQUEEN',
#  '메종 마르지엘라 퍼퓸',
#  'MAISON MARGIELA PERFUME',
#  '엠엠지엘',
#  'MMGL',
#  '코랄리크',
#  'CORALIQUE',
#  '롬앤',
#  'ROM&ND',
#  '브론슨',
#  'BRONSON',
#  '프레드페리',
#  'FRED PERRY',
#  '브이투',
#  'VTWO',
#  '블랙야크',
#  'BLACKYAK',
#  '다이아몬드 레이라',
#  'DIAMOND LAYLA',
#  '아크테릭스',
#  'ARCTERYX',
#  '블루엘리펀트',
#  'BLUE ELEPHANT',
#  '솔티',
#  'SORTIE',
#  '버버리',
#  'BURBERRY',
#  '비에스래빗',
#  'BSRABBIT',
#  '무신사 스탠다드 키즈',
#  'MUSINSA STANDARD KIDS',
#  '효지',
#  'HYOJI',
#  '노드 아카이브',
#  'NODE ARCHIVE',
#  '유니온블루',
#  'UNION BLUE',
#  '애습',
#  'ASP',
#  '위크나인',
#  'WEEK9',
#  '엑서사이즈',
#  'EXERCISE',
#  '아트 오브 필드',
#  'ART OF FIELD',
#  '세컨모놀로그',
#  'SECONDMONO',
#  '질스튜어트액세서리',
#  'JILLSTUART ACC',
#  '포뷰트',
#  'FOR BEAUT',
#  '타미진스',
#  'TOMMY JEANS',
#  '오프 화이트',
#  'Off White',
#  '이티씨이',
#  'ETCE',
#  '2000아카이브스',
#  '2000ARCHIVES',
#  '몽클레어',
#  'MONCLER',
#  '건지 울른스',
#  'Guernsey Woollens',
#  '카시오',
#  'CASIO',
#  '감마갤러리',
#  'GAMMA GALLERY',
#  '익스프레스 홀리데이',
#  'EXPRESS HOLIDAY',
#  '노티카',
#  'NAUTICA',
#  '스톤아일랜드',
#  'STONE ISLAND',
#  '루오에스팩',
#  'LUOESPAC',
#  '아웃도어 프로덕츠',
#  'OUTDOOR PRODUCTS',
#  '인스턴트펑크',
#  'INSTANTFUNK',
#  '로아앤제인',
#  'ROANJANE',
#  '파라체이스',
#  'PARACHASE',
#  '인천펜타포트음악축제',
#  'PENTAPORT ROCK FESTIVAL',
#  '와르',
#  'WAAR',
#  '사뿐',
#  'SAPPUN',
#  '크레모아',
#  'CLAYMORE',
#  '골스튜디오',
#  'GOALSTUDIO',
#  '디어미',
#  'DEAR,ME',
#  '블론드나인',
#  'BLOND9',
#  '프루아',
#  'FFROI',
#  '글로니',
#  'GLOWNY',
#  '엘칸토',
#  'ELCANTO',
#  '닥터지',
#  'DR.G',
#  '버빌리안',
#  'BUBILIAN',
#  '시글락',
#  'ZIKLAG',
#  '마르디 메크르디 레쁘띠',
#  'MARDI MERCREDI LESPETITS',
#  '데이즈데이즈',
#  'DAZE DAYZ',
#  '세릭',
#  'CERRIC',
#  '아크메드라비',
#  'ACME DE LA VIE',
#  '벨로디네라',
#  'VALLO DE NERA',
#  '어텐션로우',
#  'ATTENTIONROW',
#  '베이프릴',
#  'BEIPRIL',
#  '선데이오프클럽',
#  'SUNDAYOFFCLUB',
#  '노앙',
#  'NOHANT',
#  '펜필드',
#  'PENFIELD',
#  '레이브',
#  'RAIVE',
#  '인사일런스 우먼',
#  'INSILENCE WOMEN',
#  '킨치',
#  'KINCHI',
#  '메러베인',
#  'MELLURBANE',
#  '레테르코모',
#  'LETTERCOMO',
#  '랩',
#  'LAP',
#  '에스네이처',
#  'SNATURE',
#  '슬릭앤이지',
#  'SLICK AND EASY',
#  '유쓰배쓰',
#  'YOUTHBATH',
#  '디랩',
#  'D.LAB',
#  '벌스데이수트',
#  'BIRTHDAYSUIT',
#  '내셔널 퍼블리시티',
#  'NATIONAL PUBLICITY',
#  '행텐',
#  'HANGTEN',
#  '이스트팩',
#  'EASTPAK',
#  '에스릿 스튜디오',
#  'SLIT STUDIO',
#  '노이아고',
#  'NOIAGO',
#  '노운',
#  'NOUN',
#  '낫 유어 로즈',
#  'NOT YOUR ROSE',
#  '투쿨포스쿨',
#  'TOO COOL FOR SCHOOL',
#  '리바이스',
#  "LEVI'S",
#  '이자벨마랑',
#  'ISABEL MARANT',
#  '핏플랍',
#  'FITFLOP',
#  '테네르',
#  'TENER',
#  '이에이',
#  'IEY',
#  '아틀리에파크',
#  'ATELIERPARK',
#  '브라바도',
#  'BRAVADO',
#  '디얼스',
#  'THE EARTH',
#  '피아네르',
#  'PIANER',
#  '신지모루',
#  'SINJIMORU',
#  '멜리사',
#  'MELISSA',
#  '스칼렛또블랙',
#  'SCALETTOBLACK',
#  '알에스씨',
#  'RSC',
#  '에트몽',
#  'ETMON',
#  '스노우피크',
#  'SNOWPEAK',
#  '투큐브',
#  '2CUBE',
#  '세인트제임스',
#  'SAINT JAMES',
#  '헬리녹스',
#  'HELINOX',
#  ...]

# %%
len(brand)
# Out:
# 2000

# %%
total_brand = []

# %%
total_brand.extend(brand)
total_brand
