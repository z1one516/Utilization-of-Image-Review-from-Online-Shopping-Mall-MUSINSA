# %% [markdown]
# <a href="https://colab.research.google.com/github/ASAC-DL/MUSINSA/blob/main/%EC%9D%B4%EB%AF%B8%EC%A7%80%EC%9C%A0%EC%82%AC%EB%8F%84%EC%B8%A1%EC%A0%95(VGG16).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import Model
from sklearn.metrics.pairwise import cosine_similarity
from pathlib import Path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from PIL import Image
from numpy import dot
from numpy.linalg import norm

# %% [markdown]
# # Feature 추출 함수 정의

# %%
class FeatureExtractor:
  def __init__(self):
    # Use VGG-16 as the architecture and ImageNet for the weight
    base_model = VGG16(weights='imagenet')
    # Customize the model to return features from fully-connected layer
    self.model = Model(inputs=base_model.input, outputs=base_model.get_layer('fc1').output)

  def extract(self, img):
  # Resize the image
    img = img.resize((224, 224))
    # Convert the image color space
    img = img.convert('RGB')
    # Reformat the image
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    # Extract Features
    feature = self.model.predict(x)[0]
    return feature / np.linalg.norm(feature)

# %% [markdown]
# # Feature 추출

# %%
features = []
img_paths = []

fe = FeatureExtractor()
# Save Image Feature Vector with Database Images
for i in range(0, 2000):

  if i%100 == 0:
    print(i)
  
  try:
    path = '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail' 
    # path = '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass'   # 특징을 추출할 파일 경로

    os.chdir(path)
    files = os.listdir(path)
    image_path = '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/{}'.format(files[i]) # 파일 속 이미지 파일 이름
    img_paths.append(image_path)

    # Extract Features
    feature = fe.extract(img=Image.open(image_path))

    features.append(feature)
    # Save the Numpy array (.npy) on designated path
    feature_path = "/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/features/" + files[i].strip('.jpg') + ".npy"     # Feature를 저장할 폴더 경로
    np.save(feature_path, feature)
  except Exception as e:
    print('예외가 발생했습니다.', e)

# %%
len(features)
# Out:
# 1999

# %% [markdown]
# # 알고 싶은 이미지 설정 및 비교

# %%
# Insert the image query
img = Image.open("/content/2758349_1_500.jpg") # 알고 싶은 이미지 경로
# Extract its features
query = fe.extract(img)

# Calculate the similarity (distance) between images # 유사도 비교
dists = np.linalg.norm(features - query, axis=1)

# Extract 30 images that have lowest distance # 가장 가까운 30개의 사진 추천
ids = np.argsort(dists)[:30]

scores = [(dists[id], img_paths[id], id) for id in ids]
# Visualize the result
axes=[]
fig=plt.figure(figsize=(8,8))
for a in range(5*6):
    score = scores[a]
    axes.append(fig.add_subplot(5, 6, a+1))
    subplot_title=str(round(score[0],2)) + "/m" + str(score[2]+1)
    axes[-1].set_title(subplot_title)  
    plt.axis('off')
    plt.imshow(Image.open(score[1]))
fig.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
a = features[0]
a
# Out:
# array([0.        , 0.00935582, 0.0005475 , ..., 0.        , 0.02757981,
#        0.        ], dtype=float32)

# %%
b = a.reshape(-1,2)
b.shape
# Out:
# (2048, 2)

# %%
# Insert the image query
img = Image.open("/content/2758349_1_500.jpg") # 알고 싶은 이미지 경로
# Extract its features
query = fe.extract(img)
q = query.reshape(-1,2)
q.shape
# Out:
# 1/1 [==============================] - 1s 1s/step
# (2048, 2)

# %%
f = features
n = []
for ff in f:
  fff = ff.reshape(-1,2)
  n.append(fff)

n[0].shape
for f in n:
  dists = np.linalg.norm(cosine_similarity(f,q), axis=1)

dists
# Out:
# array([24.19995 ,  0.      ,  0.      , ..., 22.368782, 22.368782,
#        24.272053], dtype=float32)

# %%
# Insert the image query
img = Image.open("/content/2758349_1_500.jpg") # 알고 싶은 이미지 경로
# Extract its features
query = fe.extract(img)

# Calculate the similarity (distance) between images # 유사도 비교
dists = np.linalg.norm(features - query, axis=1)
dists
# Out:
# 1/1 [==============================] - 1s 541ms/step
# array([1.2812682, 1.2630246, 1.2833325, ..., 1.2142009, 1.238798 ,
#        1.2381095], dtype=float32)

# %%
# Insert the image query
img = Image.open("/content/2758349_1_500.jpg") # 알고 싶은 이미지 경로
# Extract its features
query = fe.extract(img)
q = query.reshape(-1,2)


# 코사인 유사도 함수 
# for feature in features:

#   two_d = feature.reshape(-1,2)

#   dists = cosine_similarity(two_d, q)
dists = np.linalg.norm(cosine_similarity(feature,q), axis=1)

# Extract 30 images that have lowest distance # 가장 가까운 30개의 사진 추천
ids = np.argsort(dists)[:30]

scores = [(dists[id], img_paths[id], id) for id in ids]
# Visualize the result
axes=[]
fig=plt.figure(figsize=(8,8))
for a in range(5*6):
    score = scores[a]
    axes.append(fig.add_subplot(5, 6, a+1))
    subplot_title=str(round(score[0],2)) + "/m" + str(score[2]+1)
    axes[-1].set_title(subplot_title)  
    plt.axis('off')
    plt.imshow(Image.open(score[1]))
fig.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 1s 518ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-1110126c7de7> in <cell line: 17>()
#      15 ids = np.argsort(dists)[:30]
#      16
# ---> 17 scores = [(dists[id], img_paths[id], id) for id in ids]
#      18 # Visualize the result
#      19 axes=[]
#
# <ipython-input-112-1110126c7de7> in <listcomp>(.0)
#      15 ids = np.argsort(dists)[:30]
#      16
# ---> 17 scores = [(dists[id], img_paths[id], id) for id in ids]
#      18 # Visualize the result
#      19 axes=[]
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
id = np.argsort(dists)
iscores = [(dists[i], img_paths[i], i) for i in id]

# %%
iscores
# Out:
# [(1.1489432,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2870818_37416297_0.jpg',
#   3),
#  (1.1719174,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2757396_35300115_0.jpg',
#   38),
#  (1.1747797,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2843802_34667945_0.jpg',
#   18),
#  (1.1772726,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2786221_33651118_0.jpg',
#   23),
#  (1.1836991,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2900517_35606856_0.jpg',
#   16),
#  (1.1859818,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2789926_32950238_0.jpg',
#   21),
#  (1.1887257,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2928418_36357327_0.jpg',
#   6),
#  (1.1954982,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2900517_37229730_0.jpg',
#   12),
#  (1.1962214,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2852183_35664381_0.jpg',
#   34),
#  (1.196815,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2792632_34808996_0.jpg',
#   9),
#  (1.1973627,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2786365_35395467_0.jpg',
#   37),
#  (1.2003269,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2844453_37332512_0.jpg',
#   27),
#  (1.2009332,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2786223_35599499_0.jpg',
#   35),
#  (1.2012955,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2852209_36406919_0.jpg',
#   33),
#  (1.2038313,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2757275_37039570_0.jpg',
#   29),
#  (1.2067671,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2885531_35700088_0.jpg',
#   15),
#  (1.2103922,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2843782_34876571_0.jpg',
#   17),
#  (1.211648,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2763879_33912116_0.jpg',
#   52),
#  (1.2138098,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2870831_36274062_0.jpg',
#   7),
#  (1.2165595,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2763906_36189352_0.jpg',
#   49),
#  (1.2178829,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2910731_37281374_0.jpg',
#   4),
#  (1.2180791,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2870831_36547671_0.jpg',
#   5),
#  (1.2196839,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2905852_35662416_0.jpg',
#   50),
#  (1.2212037,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2905894_37323990_0.jpg',
#   44),
#  (1.2228087,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2792633_36674269_0.jpg',
#   8),
#  (1.2241863,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2757313_37238943_0.jpg',
#   28),
#  (1.2246234,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2763887_35594244_0.jpg',
#   51),
#  (1.225449,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2895355_35439162_0.jpg',
#   36),
#  (1.2276995,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2843802_36472914_0.jpg',
#   13),
#  (1.2350912,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2885540_37586117_0.jpg',
#   11),
#  (1.2369314,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2792627_34109590_0.jpg',
#   10),
#  (1.2369711,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2796484_33103893_0.jpg',
#   53),
#  (1.2436426,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2786286_34464802_0.jpg',
#   39),
#  (1.2450118,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2758352_33848110_0.jpg',
#   22),
#  (1.2460271,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2786352_34073914_0.jpg',
#   42),
#  (1.2473279,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2785356_33178741_0.jpg',
#   0),
#  (1.2493858,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2843801_33754835_0.jpg',
#   20),
#  (1.2496492,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2905854_36491762_0.jpg',
#   48),
#  (1.250138,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2786360_36957083_0.jpg',
#   30),
#  (1.2523165,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2844455_37337713_0.jpg',
#   26),
#  (1.2632735,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2843782_36062602_0.jpg',
#   14),
#  (1.2670199,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2786224_37477367_0.jpg',
#   25),
#  (1.27027,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2852179_37553754_0.jpg',
#   24),
#  (1.2710572,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2859670_35844778_0.jpg',
#   54),
#  (1.2735991,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2895418_36807561_0.jpg',
#   31),
#  (1.2763059,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2905807_37316961_0.jpg',
#   45),
#  (1.2766142,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2757343_34289307_0.jpg',
#   40),
#  (1.2822707,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2843782_34623916_0.jpg',
#   19),
#  (1.2823775,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2896589_36749069_0.jpg',
#   1),
#  (1.283447,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2852242_33818891_0.jpg',
#   43),
#  (1.2885919,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2905815_37310611_0.jpg',
#   46),
#  (1.2915274,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2870818_34713564_0.jpg',
#   2),
#  (1.2946656,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2895355_36507634_0.jpg',
#   32),
#  (1.2975596,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2844447_34243153_0.jpg',
#   41),
#  (1.3127785,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2905833_36773605_0.jpg',
#   47)]

# %%
items = ['2758352','2758349','2758354','2758348','2758347','2758346','3081567']

# %%
test = []
for s in iscores:
  for item in items:
    if item in s[1]:
      test.append(s)
      print(s)
# Out:
# (1.2450118, '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/pass/2758352_33848110_0.jpg', 22)

# %%
len(test)
# Out:
# 286

# %%
9/len(test)
# Out:
# 0.03146853146853147

# %%
scores
# Out:
# [(0.8273115,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758359_32896327_0.jpg',
#   422),
#  (0.9387969,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2895508_34630177_0.jpg',
#   230),
#  (0.94195384,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758354_33573328_0.jpg',
#   352),
#  (0.9523028,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2885540_35293901_0.jpg',
#   1106),
#  (0.9630525,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758354_34571536_0.jpg',
#   237),
#  (0.98793274,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2905882_35189100_0.jpg',
#   915),
#  (0.9937148,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2905816_37486640_0.jpg',
#   461),
#  (0.99811053,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758349_35966198_0.jpg',
#   1862),
#  (0.999298,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2852215_35686691_0.jpg',
#   1956),
#  (0.9995768,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2905894_36534587_0.jpg',
#   571),
#  (1.0004568,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758354_35849861_0.jpg',
#   1906),
#  (1.0073515,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758349_36055467_0.jpg',
#   1828),
#  (1.0121428,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2905839_35168688_0.jpg',
#   918),
#  (1.015989,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758354_32941328_0.jpg',
#   419),
#  (1.0272608,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2905860_35473730_0.jpg',
#   848),
#  (1.0354334,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2895365_34722264_0.jpg',
#   216),
#  (1.0380638,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758349_36758333_0.jpg',
#   1611),
#  (1.0393554,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758354_36171725_0.jpg',
#   1783),
#  (1.0410687,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2786357_34553797_0.jpg',
#   1334),
#  (1.047339,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2929749_35210827_0.jpg',
#   124),
#  (1.0556461,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2909026_35671758_1.jpg',
#   1961),
#  (1.0571141,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2885516_35757707_0.jpg',
#   1018),
#  (1.057214,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2907631_35795612_0.jpg',
#   735),
#  (1.0573386,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2905883_36972748_0.jpg',
#   508),
#  (1.0590781,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2857031_34337515_0.jpg',
#   1221),
#  (1.0591729,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758350_35652361_0.jpg',
#   1977),
#  (1.0597178,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758359_35477320_0.jpg',
#   26),
#  (1.0657432,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2786325_37330462_0.jpg',
#   1454),
#  (1.0671145,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758349_37031374_0.jpg',
#   1547),
#  (1.0697328,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2843801_33880482_0.jpg',
#   1254)]

# %%
same = []
for s in scores:
  for item in items:
    if item in s[1]:
      same.append(s)
      print(s)
# Out:
# (0.94195384, '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758354_33573328_0.jpg', 352)
# (0.9630525, '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758354_34571536_0.jpg', 237)
# (0.99811053, '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758349_35966198_0.jpg', 1862)
# (1.0004568, '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758354_35849861_0.jpg', 1906)
# (1.0073515, '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758349_36055467_0.jpg', 1828)
# (1.015989, '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758354_32941328_0.jpg', 419)
# (1.0380638, '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758349_36758333_0.jpg', 1611)
# (1.0393554, '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758354_36171725_0.jpg', 1783)
# (1.0671145, '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758349_37031374_0.jpg', 1547)

# %%
same
# Out:
# [(0.94195384,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758354_33573328_0.jpg',
#   352),
#  (0.9630525,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758354_34571536_0.jpg',
#   237),
#  (0.99811053,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758349_35966198_0.jpg',
#   1862),
#  (1.0004568,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758354_35849861_0.jpg',
#   1906),
#  (1.0073515,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758349_36055467_0.jpg',
#   1828),
#  (1.015989,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758354_32941328_0.jpg',
#   419),
#  (1.0380638,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758349_36758333_0.jpg',
#   1611),
#  (1.0393554,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758354_36171725_0.jpg',
#   1783),
#  (1.0671145,
#   '/content/drive/MyDrive/T아카데미-데이터분석과정/DL_PROJECT/fail/2758349_37031374_0.jpg',
#   1547)]

# %%
axes=[]
fig=plt.figure(figsize=(8,8))
for a in range(3*3):
    score = same[a]
    axes.append(fig.add_subplot(5, 6, a+1))
    subplot_title=str(round(score[0],2)) + "/m" + str(score[2]+1)
    axes[-1].set_title(subplot_title)  
    plt.axis('off')
    plt.imshow(Image.open(score[1]))
fig.tight_layout()
plt.show()
