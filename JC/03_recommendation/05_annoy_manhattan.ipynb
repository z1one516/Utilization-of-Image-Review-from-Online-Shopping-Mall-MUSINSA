# %%
pip install tensorflow_hub
# Out:
# Requirement already satisfied: tensorflow_hub in c:\users\nt550009\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow_hub) (1.24.3)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow_hub) (4.23.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\nt550009\anaconda3\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.11)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.23.2)
# Requirement already satisfied: setuptools in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (67.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.54.2)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\nt550009\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\nt550009\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in c:\users\nt550009\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.19.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.29.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\nt550009\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\nt550009\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nt550009\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\nt550009\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\nt550009\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\nt550009\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nt550009\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nt550009\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nt550009\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\nt550009\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\nt550009\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\nt550009\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\nt550009\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\nt550009\anaconda3\lib\site-packages)

# %%
pip install Cmake
# Out:
# Requirement already satisfied: Cmake in c:\users\nt550009\anaconda3\lib\site-packages (3.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\nt550009\anaconda3\lib\site-packages (0.0.post5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade numpy scipy
# Out:
# Requirement already satisfied: numpy in c:\users\nt550009\anaconda3\lib\site-packages (1.23.5)
# Collecting numpy
#   Using cached numpy-1.25.0-cp310-cp310-win_amd64.whl (15.0 MB)
# Requirement already satisfied: scipy in c:\users\nt550009\anaconda3\lib\site-packages (1.10.1)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Rolling back uninstall of numpy
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy-1.23.5.dist-info\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\~umpy-1.23.5.dist-info
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\.libs\libopenblas.fb5ae2tyxyh2ijrdkgdgq3xbklktf43h.gfortran-win_amd64.dll
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-gxm4cq94\libopenblas.fb5ae2tyxyh2ijrdkgdgq3xbklktf43h.gfortran-win_amd64.dll
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__config__.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__config__.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__init__.cython-30.pxd
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__init__.cython-30.pxd
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__init__.pxd
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__init__.pxd
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__init__.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__init__.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__init__.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__init__.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__pycache__\__config__.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__pycache__\__config__.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__pycache__\__init__.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__pycache__\__init__.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__pycache__\_distributor_init.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__pycache__\_distributor_init.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__pycache__\_globals.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__pycache__\_globals.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__pycache__\_pytesttester.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__pycache__\_pytesttester.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__pycache__\_version.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__pycache__\_version.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__pycache__\conftest.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__pycache__\conftest.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__pycache__\ctypeslib.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__pycache__\ctypeslib.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__pycache__\dual.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__pycache__\dual.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__pycache__\matlib.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__pycache__\matlib.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__pycache__\setup.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__pycache__\setup.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\__pycache__\version.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\__pycache__\version.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\_distributor_init.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\_distributor_init.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\_globals.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\_globals.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\_pyinstaller\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\~pyinstaller
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\_pytesttester.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\_pytesttester.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\_pytesttester.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\_pytesttester.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\_typing\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\~typing
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\_version.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\_version.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__init__.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__init__.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__pycache__\__init__.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__pycache__\__init__.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__pycache__\_array_object.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__pycache__\_array_object.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__pycache__\_constants.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__pycache__\_constants.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__pycache__\_creation_functions.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__pycache__\_creation_functions.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__pycache__\_data_type_functions.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__pycache__\_data_type_functions.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__pycache__\_dtypes.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__pycache__\_dtypes.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__pycache__\_elementwise_functions.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__pycache__\_elementwise_functions.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__pycache__\_manipulation_functions.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__pycache__\_manipulation_functions.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__pycache__\_searching_functions.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__pycache__\_searching_functions.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__pycache__\_set_functions.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__pycache__\_set_functions.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__pycache__\_sorting_functions.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__pycache__\_sorting_functions.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__pycache__\_statistical_functions.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__pycache__\_statistical_functions.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__pycache__\_typing.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__pycache__\_typing.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__pycache__\_utility_functions.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__pycache__\_utility_functions.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__pycache__\linalg.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__pycache__\linalg.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\__pycache__\setup.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\__pycache__\setup.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\_array_object.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\_array_object.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\_constants.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\_constants.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\_creation_functions.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\_creation_functions.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\_data_type_functions.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\_data_type_functions.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\_dtypes.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\_dtypes.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\_elementwise_functions.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\_elementwise_functions.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\_manipulation_functions.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\_manipulation_functions.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\_searching_functions.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\_searching_functions.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\_set_functions.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\_set_functions.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\_sorting_functions.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\_sorting_functions.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\_statistical_functions.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\_statistical_functions.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\_typing.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\_typing.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\_utility_functions.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\_utility_functions.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\linalg.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\linalg.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\setup.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\setup.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\tests\__init__.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\tests\__init__.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\tests\__pycache__\__init__.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\tests\__pycache__\__init__.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\tests\__pycache__\test_array_object.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\tests\__pycache__\test_array_object.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\tests\__pycache__\test_creation_functions.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\tests\__pycache__\test_creation_functions.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\tests\__pycache__\test_data_type_functions.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\tests\__pycache__\test_data_type_functions.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\tests\__pycache__\test_elementwise_functions.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\tests\__pycache__\test_elementwise_functions.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\tests\__pycache__\test_set_functions.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\tests\__pycache__\test_set_functions.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\tests\__pycache__\test_sorting_functions.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\tests\__pycache__\test_sorting_functions.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\tests\__pycache__\test_validation.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\tests\__pycache__\test_validation.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\tests\test_array_object.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\tests\test_array_object.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\tests\test_creation_functions.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\tests\test_creation_functions.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\tests\test_data_type_functions.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\tests\test_data_type_functions.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\tests\test_elementwise_functions.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\tests\test_elementwise_functions.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\tests\test_set_functions.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\tests\test_set_functions.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\tests\test_sorting_functions.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\tests\test_sorting_functions.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\array_api\tests\test_validation.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\array_api\tests\test_validation.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\compat\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\~ompat
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\conftest.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\conftest.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\__init__.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\__init__.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\__init__.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\__init__.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\__pycache__\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\core\~_pycache__
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_add_newdocs.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_add_newdocs.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_add_newdocs_scalars.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_add_newdocs_scalars.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_asarray.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_asarray.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_asarray.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_asarray.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_dtype.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_dtype.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_dtype_ctypes.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_dtype_ctypes.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_exceptions.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_exceptions.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_internal.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_internal.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_internal.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_internal.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_machar.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_machar.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_methods.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_methods.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_multiarray_tests.cp310-win_amd64.pyd
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_multiarray_tests.cp310-win_amd64.pyd
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_multiarray_umath.cp310-win_amd64.pyd
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_multiarray_umath.cp310-win_amd64.pyd
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_operand_flag_tests.cp310-win_amd64.pyd
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_operand_flag_tests.cp310-win_amd64.pyd
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_rational_tests.cp310-win_amd64.pyd
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_rational_tests.cp310-win_amd64.pyd
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_simd.cp310-win_amd64.pyd
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_simd.cp310-win_amd64.pyd
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_string_helpers.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_string_helpers.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_struct_ufunc_tests.cp310-win_amd64.pyd
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_struct_ufunc_tests.cp310-win_amd64.pyd
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_type_aliases.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_type_aliases.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_type_aliases.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_type_aliases.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_ufunc_config.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_ufunc_config.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_ufunc_config.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_ufunc_config.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\_umath_tests.cp310-win_amd64.pyd
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\_umath_tests.cp310-win_amd64.pyd
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\arrayprint.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\arrayprint.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\arrayprint.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\arrayprint.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\cversions.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\cversions.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\defchararray.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\defchararray.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\defchararray.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\defchararray.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\einsumfunc.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\einsumfunc.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\einsumfunc.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\einsumfunc.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\fromnumeric.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\fromnumeric.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\fromnumeric.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\fromnumeric.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\function_base.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\function_base.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\function_base.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\function_base.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\generate_numpy_api.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\generate_numpy_api.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\getlimits.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\getlimits.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\getlimits.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\getlimits.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\.doxyfile
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\.doxyfile
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\__multiarray_api.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\__multiarray_api.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\__ufunc_api.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\__ufunc_api.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\_neighborhood_iterator_imp.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\_neighborhood_iterator_imp.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\_numpyconfig.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\_numpyconfig.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\arrayobject.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\arrayobject.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\arrayscalars.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\arrayscalars.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\experimental_dtype_api.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\experimental_dtype_api.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\halffloat.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\halffloat.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\libdivide\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\core\include\numpy\~ibdivide
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\multiarray_api.txt
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\multiarray_api.txt
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\ndarrayobject.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\ndarrayobject.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\ndarraytypes.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\ndarraytypes.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\noprefix.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\noprefix.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\npy_1_7_deprecated_api.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_3kcompat.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\npy_3kcompat.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_common.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\npy_common.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_cpu.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\npy_cpu.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_endian.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\npy_endian.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_interrupt.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\npy_interrupt.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_math.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\npy_math.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_no_deprecated_api.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\npy_no_deprecated_api.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\npy_os.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\npy_os.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\numpyconfig.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\numpyconfig.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\old_defines.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\old_defines.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\oldnumeric.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\oldnumeric.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\random\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\core\include\numpy\~andom
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\ufunc_api.txt
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\ufunc_api.txt
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\ufuncobject.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\ufuncobject.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\include\numpy\utils.h
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\include\numpy\utils.h
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\lib\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\core\~ib
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\memmap.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\memmap.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\memmap.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\memmap.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\multiarray.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\multiarray.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\multiarray.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\multiarray.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\numeric.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\numeric.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\numeric.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\numeric.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\numerictypes.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\numerictypes.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\numerictypes.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\numerictypes.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\overrides.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\overrides.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\records.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\records.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\records.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\records.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\setup.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\setup.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\setup_common.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\setup_common.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\shape_base.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\shape_base.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\shape_base.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\shape_base.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\tests\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\core\~ests
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\umath.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\umath.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\core\umath_tests.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\core\umath_tests.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\ctypeslib.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\ctypeslib.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\ctypeslib.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\ctypeslib.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__config__.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__config__.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__init__.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__init__.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__init__.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__init__.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\__config__.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\__config__.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\__init__.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\__init__.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\_shell_utils.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\_shell_utils.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\armccompiler.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\armccompiler.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\ccompiler.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\ccompiler.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\ccompiler_opt.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\ccompiler_opt.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\conv_template.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\conv_template.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\core.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\core.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\cpuinfo.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\cpuinfo.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\exec_command.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\exec_command.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\extension.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\extension.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\from_template.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\from_template.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\intelccompiler.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\intelccompiler.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\lib2def.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\lib2def.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\line_endings.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\line_endings.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\log.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\log.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\mingw32ccompiler.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\mingw32ccompiler.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\misc_util.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\misc_util.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\msvc9compiler.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\msvc9compiler.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\msvccompiler.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\msvccompiler.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\npy_pkg_config.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\npy_pkg_config.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\numpy_distribution.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\numpy_distribution.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\pathccompiler.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\pathccompiler.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\setup.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\setup.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\system_info.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\system_info.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\__pycache__\unixccompiler.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\__pycache__\unixccompiler.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\_shell_utils.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\_shell_utils.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\armccompiler.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\armccompiler.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\ccompiler.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\ccompiler.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\ccompiler_opt.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\ccompiler_opt.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_asimd.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_asimd.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_asimddp.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_asimddp.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_asimdfhm.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_asimdfhm.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_asimdhp.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_asimdhp.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_avx.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_avx.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_avx2.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_avx2.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_avx512_clx.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_avx512_clx.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_avx512_cnl.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_avx512_cnl.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_avx512_icl.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_avx512_icl.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_avx512_knl.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_avx512_knl.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_avx512_knm.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_avx512_knm.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_avx512_skx.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_avx512_skx.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_avx512cd.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_avx512cd.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_avx512f.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_avx512f.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_f16c.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_f16c.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_fma3.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_fma3.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_fma4.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_fma4.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_neon.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_neon.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_neon_fp16.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_neon_fp16.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_neon_vfpv4.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_neon_vfpv4.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_popcnt.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_popcnt.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_sse.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_sse.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_sse2.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_sse2.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_sse3.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_sse3.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_sse41.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_sse41.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_sse42.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_sse42.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_ssse3.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_ssse3.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_vsx.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_vsx.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_vsx2.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_vsx2.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_vsx3.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_vsx3.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_vsx4.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_vsx4.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_vx.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_vx.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_vxe.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_vxe.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_vxe2.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_vxe2.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\cpu_xop.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\cpu_xop.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\extra_avx512bw_mask.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\extra_avx512bw_mask.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\extra_avx512dq_mask.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\extra_avx512dq_mask.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\extra_avx512f_reduce.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\extra_avx512f_reduce.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\extra_vsx4_mma.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\extra_vsx4_mma.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\extra_vsx_asm.c
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\distutils\checks\extra_vsx_asm.c
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\distutils\checks\test_flags.c
# ...
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\src\f2cmap\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\f2py\tests\src\~2cmap
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\src\kind\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\f2py\tests\src\~ind
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\src\mixed\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\f2py\tests\src\~ixed
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\src\module_data\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\f2py\tests\src\~odule_data
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\src\negative_bounds\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\f2py\tests\src\~egative_bounds
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\src\parameter\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\f2py\tests\src\~arameter
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\src\quoted_character\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\f2py\tests\src\~uoted_character
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\src\regression\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\f2py\tests\src\~egression
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\src\return_character\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\f2py\tests\src\~eturn_character
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\src\return_complex\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\f2py\tests\src\~eturn_complex
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\src\return_integer\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\f2py\tests\src\~eturn_integer
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\src\return_logical\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\f2py\tests\src\~eturn_logical
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\src\return_real\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\f2py\tests\src\~eturn_real
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\src\size\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\f2py\tests\src\~ize
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\src\string\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\f2py\tests\src\~tring
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_abstract_interface.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_abstract_interface.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_array_from_pyobj.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_array_from_pyobj.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_assumed_shape.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_assumed_shape.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_block_docstring.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_block_docstring.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_callback.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_callback.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_common.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_common.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_compile_function.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_compile_function.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_crackfortran.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_crackfortran.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_f2cmap.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_f2cmap.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_f2py2e.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_f2py2e.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_kind.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_kind.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_mixed.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_mixed.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_module_doc.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_module_doc.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_parameter.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_parameter.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_quoted_character.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_quoted_character.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_regression.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_regression.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_return_character.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_return_character.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_return_complex.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_return_complex.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_return_integer.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_return_integer.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_return_logical.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_return_logical.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_return_real.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_return_real.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_semicolon_split.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_semicolon_split.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_size.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_size.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_string.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_string.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\test_symbolic.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\test_symbolic.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\tests\util.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\tests\util.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\f2py\use_rules.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\f2py\use_rules.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\fft\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\~ft
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\lib\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\~ib
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\license.txt
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\license.txt
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\linalg\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\~inalg
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\ma\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\~a
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\matlib.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\matlib.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\matrixlib\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\~atrixlib
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\polynomial\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\~olynomial
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\py.typed
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\py.typed
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\random\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\~andom
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\setup.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\setup.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\testing\__init__.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\testing\__init__.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\testing\__init__.pyi
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\testing\__init__.pyi
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\testing\__pycache__\__init__.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\testing\__pycache__\__init__.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\testing\__pycache__\print_coercion_tables.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\testing\__pycache__\print_coercion_tables.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\testing\__pycache__\setup.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\testing\__pycache__\setup.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\testing\__pycache__\utils.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\testing\__pycache__\utils.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\testing\_private\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\testing\~private
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\testing\print_coercion_tables.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\testing\print_coercion_tables.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\testing\setup.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\testing\setup.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\testing\tests\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\testing\~ests
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\testing\utils.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\testing\utils.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\__init__.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\__init__.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\__pycache__\__init__.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\__pycache__\__init__.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\__pycache__\test__all__.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\__pycache__\test__all__.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\__pycache__\test_ctypeslib.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\__pycache__\test_ctypeslib.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\__pycache__\test_matlib.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\__pycache__\test_matlib.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\__pycache__\test_numpy_version.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\__pycache__\test_numpy_version.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\__pycache__\test_public_api.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\__pycache__\test_public_api.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\__pycache__\test_reloading.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\__pycache__\test_reloading.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\__pycache__\test_scripts.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\__pycache__\test_scripts.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\__pycache__\test_warnings.cpython-310.pyc
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\__pycache__\test_warnings.cpython-310.pyc
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\test__all__.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\test__all__.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\test_ctypeslib.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\test_ctypeslib.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\test_matlib.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\test_matlib.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\test_numpy_version.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\test_numpy_version.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\test_public_api.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\test_public_api.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\test_reloading.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\test_reloading.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\test_scripts.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\test_scripts.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\tests\test_warnings.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\tests\test_warnings.py
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\typing\
#    from C:\Users\NT550009\anaconda3\Lib\site-packages\numpy\~yping
#   Moving to c:\users\nt550009\anaconda3\lib\site-packages\numpy\version.py
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-dilnoum8\version.py
#   Moving to c:\users\nt550009\anaconda3\scripts\f2py.exe
#    from C:\Users\NT550009\AppData\Local\Temp\pip-uninstall-acywk8ht\f2py.exe
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'C:\\Users\\NT550009\\anaconda3\\Lib\\site-packages\\numpy\\.libs\\libopenblas64__v0.3.23-gcc_10_3_0.dll'
# Consider using the `--user` option or check the permissions.

# %%
pip install mkl
# Out:
# Requirement already satisfied: mkl in c:\users\nt550009\anaconda3\lib\site-packages (2023.1.0)
# Requirement already satisfied: intel-openmp==2023.* in c:\users\nt550009\anaconda3\lib\site-packages (from mkl) (2023.1.0)
# Requirement already satisfied: tbb==2021.* in c:\users\nt550009\anaconda3\lib\site-packages (from mkl) (2021.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update -n base -c defaults conda
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\NT550009\anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2023.5.7~ --> pkgs/main::ca-certificates-2023.05.30-haa95532_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge/noarch::certifi-2023.5.7-~ --> pkgs/main/win-64::certifi-2023.5.7-py310haa95532_0
#   conda              conda-forge::conda-23.5.0-py310h5588d~ --> pkgs/main::conda-23.5.0-py310haa95532_0
#   openssl            conda-forge::openssl-1.1.1u-hcfcfb64_0 --> pkgs/main::openssl-1.1.1u-h2bbff1b_0
#
#
#
# Downloading and Extracting Packages
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge python-annoy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Traceback (most recent call last):
#   File "C:\Users\NT550009\anaconda3\lib\site-packages\conda\exception_handler.py", line 16, in __call__
#   File "C:\Users\NT550009\anaconda3\lib\site-packages\conda\cli\main.py", line 70, in main_subshell
#   File "C:\Users\NT550009\anaconda3\lib\site-packages\conda\cli\conda_argparse.py", line 65, in generate_parser
#   File "C:\Users\NT550009\anaconda3\lib\site-packages\conda\cli\conda_argparse.py", line 152, in __init__
#   File "C:\Users\NT550009\anaconda3\lib\site-packages\conda\base\context.py", line 502, in plugin_manager
#   File "C:\Users\NT550009\anaconda3\lib\site-packages\conda\plugins\__init__.py", line 3, in <module>
#   File "C:\Users\NT550009\anaconda3\lib\site-packages\conda\plugins\hookspec.py", line 9, in <module>
# ModuleNotFoundError: No module named 'conda.plugins.types'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\NT550009\anaconda3\Scripts\conda-script.py", line 12, in <module>
#     sys.exit(main())
#   File "C:\Users\NT550009\anaconda3\lib\site-packages\conda\cli\main.py", line 129, in main
#   File "C:\Users\NT550009\anaconda3\lib\site-packages\conda\exception_handler.py", line 376, in conda_exception_handler
#   File "C:\Users\NT550009\anaconda3\lib\site-packages\conda\exception_handler.py", line 19, in __call__
#   File "C:\Users\NT550009\anaconda3\lib\site-packages\conda\exception_handler.py", line 51, in handle_exception
# ModuleNotFoundError: No module named 'conda.exceptions'
# 배치 파일을 찾을 수 없습니다.
# 배치 파일을 찾을 수 없습니다.

# %%
pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\nt550009\anaconda3\lib\site-packages (2.0.1)
# Requirement already satisfied: filelock in c:\users\nt550009\anaconda3\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\nt550009\anaconda3\lib\site-packages (from torch) (4.6.3)
# Requirement already satisfied: sympy in c:\users\nt550009\anaconda3\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\nt550009\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\nt550009\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nt550009\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\nt550009\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torchvision
# Out:
# Requirement already satisfied: torchvision in c:\users\nt550009\anaconda3\lib\site-packages (0.15.2)
# Requirement already satisfied: numpy in c:\users\nt550009\anaconda3\lib\site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: requests in c:\users\nt550009\anaconda3\lib\site-packages (from torchvision) (2.29.0)
# Requirement already satisfied: torch==2.0.1 in c:\users\nt550009\anaconda3\lib\site-packages (from torchvision) (2.0.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\nt550009\anaconda3\lib\site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: filelock in c:\users\nt550009\anaconda3\lib\site-packages (from torch==2.0.1->torchvision) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\nt550009\anaconda3\lib\site-packages (from torch==2.0.1->torchvision) (4.6.3)
# Requirement already satisfied: sympy in c:\users\nt550009\anaconda3\lib\site-packages (from torch==2.0.1->torchvision) (1.12)
# Requirement already satisfied: networkx in c:\users\nt550009\anaconda3\lib\site-packages (from torch==2.0.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in c:\users\nt550009\anaconda3\lib\site-packages (from torch==2.0.1->torchvision) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nt550009\anaconda3\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nt550009\anaconda3\lib\site-packages (from requests->torchvision) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nt550009\anaconda3\lib\site-packages (from requests->torchvision) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nt550009\anaconda3\lib\site-packages (from requests->torchvision) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nt550009\anaconda3\lib\site-packages (from jinja2->torch==2.0.1->torchvision) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\nt550009\anaconda3\lib\site-packages (from sympy->torch==2.0.1->torchvision) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install git+https://github.com/openai/clip.git
# Out:
# Collecting git+https://github.com/openai/clip.gitNote: you may need to restart the kernel to use updated packages.
#
#   Cloning https://github.com/openai/clip.git to c:\users\nt550009\appdata\local\temp\pip-req-build-70hgh4x0
#   Resolved https://github.com/openai/clip.git to commit a9b1bf5920416aaeaec965c25dd9e8f98c864f16
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: ftfy in c:\users\nt550009\anaconda3\lib\site-packages (from clip==1.0) (6.1.1)
# Requirement already satisfied: regex in c:\users\nt550009\anaconda3\lib\site-packages (from clip==1.0) (2023.6.3)
# Requirement already satisfied: tqdm in c:\users\nt550009\anaconda3\lib\site-packages (from clip==1.0) (4.65.0)
# Requirement already satisfied: torch in c:\users\nt550009\anaconda3\lib\site-packages (from clip==1.0) (2.0.1)
# Requirement already satisfied: torchvision in c:\users\nt550009\anaconda3\lib\site-packages (from clip==1.0) (0.15.2)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\users\nt550009\anaconda3\lib\site-packages (from ftfy->clip==1.0) (0.2.5)
# Requirement already satisfied: filelock in c:\users\nt550009\anaconda3\lib\site-packages (from torch->clip==1.0) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\nt550009\anaconda3\lib\site-packages (from torch->clip==1.0) (4.6.3)
# Requirement already satisfied: sympy in c:\users\nt550009\anaconda3\lib\site-packages (from torch->clip==1.0) (1.12)
# Requirement already satisfied: networkx in c:\users\nt550009\anaconda3\lib\site-packages (from torch->clip==1.0) (3.1)
# Requirement already satisfied: jinja2 in c:\users\nt550009\anaconda3\lib\site-packages (from torch->clip==1.0) (3.1.2)
# Requirement already satisfied: numpy in c:\users\nt550009\anaconda3\lib\site-packages (from torchvision->clip==1.0) (1.23.5)
# Requirement already satisfied: requests in c:\users\nt550009\anaconda3\lib\site-packages (from torchvision->clip==1.0) (2.29.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\nt550009\anaconda3\lib\site-packages (from torchvision->clip==1.0) (9.4.0)
# Requirement already satisfied: colorama in c:\users\nt550009\anaconda3\lib\site-packages (from tqdm->clip==1.0) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nt550009\anaconda3\lib\site-packages (from jinja2->torch->clip==1.0) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nt550009\anaconda3\lib\site-packages (from requests->torchvision->clip==1.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nt550009\anaconda3\lib\site-packages (from requests->torchvision->clip==1.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nt550009\anaconda3\lib\site-packages (from requests->torchvision->clip==1.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nt550009\anaconda3\lib\site-packages (from requests->torchvision->clip==1.0) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in c:\users\nt550009\anaconda3\lib\site-packages (from sympy->torch->clip==1.0) (1.3.0)
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/clip.git 'C:\Users\NT550009\AppData\Local\Temp\pip-req-build-70hgh4x0'

# %%
import torch
import torchvision.transforms as T
import glob
from PIL import Image
from annoy import AnnoyIndex
from clip import clip
import numpy as np
# Out:
# C:\Users\NT550009\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\NT550009\anaconda3\lib\site-packages\numpy\.libs\libopenblas.fb5ae2tyxyh2ijrdkgdgq3xbklktf43h.gfortran-win_amd64.dll
# C:\Users\NT550009\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# # 맨해튼

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
# Torch 라이브러리의 GPU 사용 가능 여부를 확인하고, 
# 사용 가능한 경우 device 변수를 "cuda"로 설정하고, 
# 그렇지 않은 경우 "cpu"로 설정


model, _ = clip.load("ViT-B/32", device=device)
preprocess = T.Compose([
    T.Resize((224, 224)),
    T.CenterCrop(224),
    T.ToTensor()
])
# CLIP 모델을 불러옴. ViT-B/32는 CLIP 모델의 구성 중 하나
# T.Resize(224)는 이미지의 크기를 224x224로 조정하고, 
# T.CenterCrop(224)는 이미지를 가운데를 중심으로 224x224 크기로 자름

embedding_size = 512  # CLIP 모델의 특징 벡터 크기
n_trees = 100  # annoy 인덱스의 트리 개수

annoy_index = AnnoyIndex(embedding_size, 'manhattan')
# annoy 패키지의 AnnoyIndex 클래스를 사용해 Annoy 인덱스를 초기화
# 특징 벡터의 크기와 거리 측정 방법으로 manhattan 을 인수로 전달

image_files = glob.glob(r"C:\Users\NT550009\Desktop\detail_image_aggregated/*.jpg")
    
for image_id, image_file in enumerate(image_files):
    image = Image.open(image_file).convert("RGB")
    image = preprocess(image).unsqueeze(0).to(device)
    
    with torch.no_grad():
        image_features = model.encode_image(image)
        # model 객체를 사용하여 이미지를 인코딩하여 특징 벡터(임베딩)를 추출
        # encode_image() 함수는 CLIP 모델에서 이미지에 대한 특징 벡터를 계산하는 역할
    image_features = image_features.cpu().numpy().flatten()
    # Annoy 인덱스에 추가하기 위해 특징 벡터를 CPU 메모리로 이동시키고, 
    # NumPy 배열로 변환한 후 1차원으로 평탄화
    
    annoy_index.add_item(image_id, image_features)

annoy_index.build(n_trees)
# Annoy 인덱스 구축. 
# 트리 개수가 많을수록 인덱스의 정확도가 증가하지만, 구
# 축에 소요되는 시간도 더 많이 소요
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 31
#      28 image = preprocess(image).unsqueeze(0).to(device)
#      30 with torch.no_grad():
# ---> 31     image_features = model.encode_image(image)
#      32     # model 객체를 사용하여 이미지를 인코딩하여 특징 벡터(임베딩)를 추출
#      33     # encode_image() 함수는 CLIP 모델에서 이미지에 대한 특징 벡터를 계산하는 역할
#      34 image_features = image_features.cpu().numpy().flatten()
#
# File ~\anaconda3\lib\site-packages\clip\model.py:341, in CLIP.encode_image(self, image)
#     340 def encode_image(self, image):
# --> 341     return self.visual(image.type(self.dtype))
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\clip\model.py:232, in VisionTransformer.forward(self, x)
#     229 x = self.ln_pre(x)
#     231 x = x.permute(1, 0, 2)  # NLD -> LND
# --> 232 x = self.transformer(x)
#     233 x = x.permute(1, 0, 2)  # LND -> NLD
#     235 x = self.ln_post(x[:, 0, :])
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\clip\model.py:203, in Transformer.forward(self, x)
#     202 def forward(self, x: torch.Tensor):
# --> 203     return self.resblocks(x)
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\clip\model.py:190, in ResidualAttentionBlock.forward(self, x)
#     189 def forward(self, x: torch.Tensor):
# --> 190     x = x + self.attention(self.ln_1(x))
#     191     x = x + self.mlp(self.ln_2(x))
#     192     return x
#
# File ~\anaconda3\lib\site-packages\clip\model.py:187, in ResidualAttentionBlock.attention(self, x)
#     185 def attention(self, x: torch.Tensor):
#     186     self.attn_mask = self.attn_mask.to(dtype=x.dtype, device=x.device) if self.attn_mask is not None else None
# --> 187     return self.attn(x, x, x, need_weights=False, attn_mask=self.attn_mask)[0]
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\anaconda3\lib\site-packages\torch\nn\modules\activation.py:1205, in MultiheadAttention.forward(self, query, key, value, key_padding_mask, need_weights, attn_mask, average_attn_weights, is_causal)
#    1191     attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1192         query, key, value, self.embed_dim, self.num_heads,
#    1193         self.in_proj_weight, self.in_proj_bias,
#    (...)
#    1202         average_attn_weights=average_attn_weights,
#    1203         is_causal=is_causal)
#    1204 else:
# -> 1205     attn_output, attn_output_weights = F.multi_head_attention_forward(
#    1206         query, key, value, self.embed_dim, self.num_heads,
#    1207         self.in_proj_weight, self.in_proj_bias,
#    1208         self.bias_k, self.bias_v, self.add_zero_attn,
#    1209         self.dropout, self.out_proj.weight, self.out_proj.bias,
#    1210         training=self.training,
#    1211         key_padding_mask=key_padding_mask,
#    1212         need_weights=need_weights,
#    1213         attn_mask=attn_mask,
#    1214         average_attn_weights=average_attn_weights,
#    1215         is_causal=is_causal)
#    1216 if self.batch_first and is_batched:
#    1217     return attn_output.transpose(1, 0), attn_output_weights
#
# File ~\anaconda3\lib\site-packages\torch\nn\functional.py:5224, in multi_head_attention_forward(query, key, value, embed_dim_to_check, num_heads, in_proj_weight, in_proj_bias, bias_k, bias_v, add_zero_attn, dropout_p, out_proj_weight, out_proj_bias, training, key_padding_mask, need_weights, attn_mask, use_separate_proj_weight, q_proj_weight, k_proj_weight, v_proj_weight, static_k, static_v, average_attn_weights, is_causal)
#    5222 if not use_separate_proj_weight:
#    5223     assert in_proj_weight is not None, "use_separate_proj_weight is False but in_proj_weight is None"
# -> 5224     q, k, v = _in_projection_packed(query, key, value, in_proj_weight, in_proj_bias)
#    5225 else:
#    5226     assert q_proj_weight is not None, "use_separate_proj_weight is True but q_proj_weight is None"
#
# File ~\anaconda3\lib\site-packages\torch\nn\functional.py:4767, in _in_projection_packed(q, k, v, w, b)
#    4765     proj = linear(q, w, b)
#    4766     # reshape to 3, E and not E, 3 is deliberate for better memory coalescing and keeping same order as chunk()
# -> 4767     proj = proj.unflatten(-1, (3, E)).unsqueeze(0).transpose(0, -2).squeeze(-2).contiguous()
#    4768     return proj[0], proj[1], proj[2]
#    4769 else:
#    4770     # encoder-decoder attention
#
# KeyboardInterrupt:

# %%
annoy_index.save("annoy_index_manhattan.ann")

# %% [markdown]
# # Query 이미지와 유사도

# %%
import matplotlib.pyplot as plt
import torch
from PIL import Image

# %%
# 1. 쿼리 이미지 준비
query_image_path = r"C:\Users\NT550009\Desktop\recommendation\pants.jpg"
query_image = Image.open(query_image_path).convert("RGB")

# 2. 쿼리 이미지 전처리하여 특징 벡터 추출
query_preprocess = T.Compose([
    T.Resize(224),
    T.CenterCrop(224),
    T.ToTensor()
])
query_image = query_preprocess(query_image).unsqueeze(0).to(device)
with torch.no_grad():
    query_features = model.encode_image(query_image)
query_features = query_features.cpu().numpy().flatten()

# 3. Annoy 인덱스에서 유사한 사진의 인덱스 검색
n_similar_images = 29
similar_image_indices = annoy_index.get_nns_by_vector(query_features, n_similar_images)

# 4. 유사한 사진들 가져오기
similar_images = [Image.open(image_files[index]).convert("RGB") for index in similar_image_indices]

# 5. 쿼리 이미지와 유사한 사진들을 plt로 출력
fig, axes = plt.subplots(5, 6, figsize=(12, 16))

axes[0, 0].imshow(query_image.squeeze().permute(1, 2, 0))
axes[0, 0].set_title("Query Image")

for i, image in enumerate(similar_images):
    row = (i + 1) // 6
    col = (i + 1) % 6
    axes[row, col].imshow(image)
    axes[row, col].set_title(f"Similar Image {i+1}")

plt.subplots_adjust(wspace=0.3, hspace=0.5)
plt.tight_layout()
plt.show()
